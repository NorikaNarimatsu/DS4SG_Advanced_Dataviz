# %% [markdown]
# <br>
# <h1 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #f6f5f5 ; color : #fe346e; text-align: center; border-radius: 100px 100px;">PCW: Learning How to Use Folium with Crime Data in SF</h1>
# <br>

# %% [markdown]
# ### <h3 style="color:#fe346e">Overview</h3>
#
# This PCW consists of two parts.
# 1. **Tutorial: Create Interactive Map with the Folium package ~Boston~**
# - For the first part (Boston example), the code is already completed. Thus,your task is go through each cell and understand what the code is doing and how it is working. You can add in-line comment. There are several questions listed in your way, so be ready to share your answer at the class.
# 2. **Your Turn: Create Interactive Map with the Folium package ~San Francisco~**
# - For the second part (San Francisco example), you will do very similar things with part 1, but some of the code is missing. Please fill the code by yourself.

# %% [markdown]
# <html><h3 style='font-family:Garamond;background:lightgrey;  color:black; font-size:30px; padding:15px; border:3px solid #fe346e;'><center><b> Tutorial: Create Interactive Map with the Folium package ~Boston~ </b></center></h3></html>

# %% [markdown]
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; background-color: #ffffff; color: navy;">Import Libraries&nbsp;&nbsp;&nbsp;&nbsp;</h1>

# %%
import pandas as pd
import geopandas as gpd
import math
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %% [markdown]
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; background-color: #ffffff; color: navy;">Display Boston Map with folium.Map() &nbsp;&nbsp;&nbsp;&nbsp;</h1>

# %%
# Create a map
boston_map = folium.Map(location=[42.32,-71.0589], tiles='openstreetmap', zoom_start=10)

# Display the map
boston_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92c484ee0cc6603d8b0b89260816e3f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92c484ee0cc6603d8b0b89260816e3f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92c484ee0cc6603d8b0b89260816e3f7 = L.map(
#                 &quot;map_92c484ee0cc6603d8b0b89260816e3f7&quot;,
#                 {
#                     center: [42.32, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_408b2f970d36695fb0f95c8aedc072ed = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_92c484ee0cc6603d8b0b89260816e3f7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Several arguments customize the appearance of the map:
# - `location` sets the initial center of the map. We use the latitude (42.32&deg; N) and longitude (-71.0589&deg; E) of the city of Boston.
# - `tiles` changes the styling of the map; in this case, we choose the [OpenStreetMap](https://www.openstreetmap.org/#map=10/42.32/-71.0589) style.  If you're curious, you can find the other options listed [here](https://github.com/python-visualization/folium/tree/master/folium/templates/tiles).We can change this to Stamen Toner, CartoDB positron, Cartodb dark_matter, Stamen Watercolor or Stamen Terrain.
# - `zoom_start` sets the initial level of zoom of the map, where higher values zoom in closer to the map.

# %% [markdown]
# - Q: What is "zoom_start" ?
# - Q: How should I adjust "zoom_start" if I would like to make my map zoomed in?

# %% [markdown]
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; background-color: #ffffff; color: navy;">Import Data &nbsp;&nbsp;&nbsp;&nbsp;</h1>

# %% [markdown]
# For the sake of data size, **df_boston.csv** only contains the crime information under "Robbery" category.

# %%
df_boston = pd.read_csv("https://raw.githubusercontent.com/NorikaNarimatsu/DS4SG_Advanced_Dataviz/main/PCW/df_boston.csv")
df_boston.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP    OFFENSE_DESCRIPTION  \
# 0      I182079671           301            Robbery       ROBBERY - STREET
# 1      I182079520           301            Robbery       ROBBERY - STREET
# 2      I182079510           301            Robbery       ROBBERY - STREET
# 3      I182079503           301            Robbery       ROBBERY - STREET
# 4      I182079502           381            Robbery  ROBBERY - CAR JACKING
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0       B3            431      NaN  2018-10-02 16:57:00  2018     10
# 1       B2            280      NaN  2018-10-02 08:05:00  2018     10
# 2      C11            403      NaN  2018-10-02 06:40:00  2018     10
# 3      C11            253      NaN  2018-10-02 06:18:00  2018     10
# 4      C11            353      NaN  2018-10-02 00:00:00  2018     10
#
#   DAY_OF_WEEK  HOUR  UCR_PART         STREET        Lat       Long  \
# 0     Tuesday    16  Part One  BLUE HILL AVE  42.288633 -71.089904
# 1     Tuesday     8  Part One      DUDLEY ST  42.328632 -71.083099
# 2     Tuesday     6  Part One      FULLER ST  42.282481 -71.069812
# 3     Tuesday     6  Part One       BEACH ST  42.301789 -71.055142
# 4     Tuesday     0  Part One        MILL ST  42.299211 -71.052038
#
#                       Location
# 0  (42.28863337, -71.08990388)
# 1  (42.32863172, -71.08309899)
# 2  (42.28248068, -71.06981187)
# 3  (42.30178949, -71.05514183)
# 4  (42.29921088, -71.05203766)

# %% [markdown]
# To reduce the amount of data we need to fit on the map, we'll (temporarily) confine our attention to daytime robberies.

# %%
daytime_robberies = df_boston[df_boston.HOUR.isin(range(9,18))]
daytime_robberies.head()
# Out:
#    INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP OFFENSE_DESCRIPTION  \
# 0       I182079671           301            Robbery    ROBBERY - STREET
# 8       I182079383           301            Robbery    ROBBERY - STREET
# 10      I182079048           301            Robbery    ROBBERY - STREET
# 19      I182078574           301            Robbery    ROBBERY - STREET
# 20      I182078527           301            Robbery    ROBBERY - STREET
#
#    DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0        B3            431      NaN  2018-10-02 16:57:00  2018     10
# 8       C11            351      NaN  2018-10-01 16:19:00  2018     10
# 10       B2            262      NaN  2018-09-30 15:01:00  2018      9
# 19       D4            165      NaN  2018-09-11 09:40:00  2018      9
# 20       B2            327      NaN  2018-09-28 14:09:00  2018      9
#
#    DAY_OF_WEEK  HOUR  UCR_PART         STREET        Lat       Long  \
# 0      Tuesday    16  Part One  BLUE HILL AVE  42.288633 -71.089904
# 8       Monday    16  Part One     CHARLES ST  42.300785 -71.060007
# 10      Sunday    15  Part One      DUDLEY ST  42.321970 -71.072425
# 19     Tuesday     9  Part One   HARRISON AVE  42.342850 -71.065162
# 20      Friday    14  Part One    HARTFORD ST  42.317454 -71.073279
#
#                        Location
# 0   (42.28863337, -71.08990388)
# 8   (42.30078455, -71.06000691)
# 10  (42.32196970, -71.07242529)
# 19  (42.34285014, -71.06516235)
# 20  (42.31745360, -71.07327858)

# %% [markdown]
# Q: What is the column name for latitude and longtitude?

# %% [markdown]
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; background-color: #ffffff; color: navy;">Map1: folium.Marker()  &nbsp;&nbsp;&nbsp;&nbsp;</h1>
#
# We add markers to the map with folium.Marker(). Each marker below corresponds to a different robbery.

# %%
# Create a map
map1_boston = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositron', zoom_start=13)

# Add points to the map
for idx, row in daytime_robberies.iterrows():
    Marker([row['Lat'], row['Long']]).add_to(map1_boston)

# Display the map
map1_boston
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93091725647dbc0b29211ea83b6d5b42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93091725647dbc0b29211ea83b6d5b42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93091725647dbc0b29211ea83b6d5b42 = L.map(
#                 &quot;map_93091725647dbc0b29211ea83b6d5b42&quot;,
#                 {
#                     center: [42.32, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81983f7674e5fc282f66b7e50690cab7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_c8ca6dd9ff3ae7d61ce5073161182252 = L.marker(
#                 [42.28863337, -71.08990388],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_4e180f5e2b549ad92047ccbe662c0507 = L.marker(
#                 [42.30078455, -71.06000691],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_126262f1be31563b31e5b36cb5f207b8 = L.marker(
#                 [42.3219697, -71.07242529],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_6f9de8fd48bef0b4bf0d00d26f1c92bf = L.marker(
#                 [42.34285014, -71.06516235],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_1b1ec693fcc10130a140ecd74c37f3e0 = L.marker(
#                 [42.3174536, -71.07327858],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_ea739271a7b83294c77a5ede442416b1 = L.marker(
#                 [42.36489527, -71.06050249],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_87bc237f413d7b9d33943cfad0c9ae87 = L.marker(
#                 [42.28587471, -71.04247805],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_eeda81e0a9ec7dea575c41b1804810ce = L.marker(
#                 [42.33397571, -71.05463126],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_740dc397fa2ab9361f0e761055cdf6fa = L.marker(
#                 [42.28187061, -71.08751152],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_9efcf5a07ec92e673bfc8848b17838ed = L.marker(
#                 [42.3169665, -71.08254058],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_aa5e293280a58bc1e49b4929abf75b7a = L.marker(
#                 [42.29851793, -71.07499608],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_c99d19ab2e07697147fa6f9da54e215d = L.marker(
#                 [42.37945053, -71.02770085],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_21f1bdca362b23dcaabe970048c26bc9 = L.marker(
#                 [42.38133666, -71.03026947],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_40486b9a2c533a6308baa5e75dceafcd = L.marker(
#                 [42.36116347, -71.06391344],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_85fb0dd0318966bf9697ea92214a791e = L.marker(
#                 [42.35174282, -71.0627594],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_3fafbc85197252bf06d2315909ee64a4 = L.marker(
#                 [42.35913227, -71.07074326],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_d4e3167985322ae416d9ea3fdcf84d03 = L.marker(
#                 [42.35235362, -71.05815283],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_751b4c7363a8e51a90a84e6ccbc21980 = L.marker(
#                 [42.29212974, -71.07175746],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_a8cb4a5a40242d06658da825d7fd32d1 = L.marker(
#                 [42.33093363, -71.10956443],
#                 {}
#             ).addTo(map_93091725647dbc0b29211ea83b6d5b42);
#
#
#             var marker_95939db7603acdd63e44ee9f22c1480e = L.marker(
#                 [42.28631799, -71.13407707],
#                 {}
#             ).addTo(map_93091725647dbc0b29

# %% [markdown]
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; background-color: #ffffff; color: navy;">Map2: folium.plugins.MarkerCluster()  &nbsp;&nbsp;&nbsp;&nbsp;</h1>

# %% [markdown]
# If we have a lot of markers to add, `folium.plugins.MarkerCluster()` can help to declutter the map.  Each marker is added to a `MarkerCluster` object.

# %%
# Create the map
map2_boston = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositron', zoom_start=13)

# Add points to the map
mc = MarkerCluster()
for idx, row in daytime_robberies.iterrows():
    if not math.isnan(row['Long']) and not math.isnan(row['Lat']):
        mc.add_child(Marker([row['Lat'], row['Long']]))
map2_boston.add_child(mc)

# Display the map
map2_boston
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2c3004b7197e1cb5e98464f445c7804 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2c3004b7197e1cb5e98464f445c7804&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2c3004b7197e1cb5e98464f445c7804 = L.map(
#                 &quot;map_d2c3004b7197e1cb5e98464f445c7804&quot;,
#                 {
#                     center: [42.32, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_868df1a89f763b67c2b26285bc886cea = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d2c3004b7197e1cb5e98464f445c7804);
#
#
#             var marker_cluster_494ff070f6e83e1c6fc8644e07edc448 = L.markerClusterGroup(
#                 {}
#             );
#             map_d2c3004b7197e1cb5e98464f445c7804.addLayer(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_3cb8f7d1ec7e6585e4b49bc0fdc5b353 = L.marker(
#                 [42.28863337, -71.08990388],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_6c769f43b19a0f2af55fd8e39723aeea = L.marker(
#                 [42.30078455, -71.06000691],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_9703663acbd7325a096f91a7db146338 = L.marker(
#                 [42.3219697, -71.07242529],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_53f56d9825bb18461f462092ed199d55 = L.marker(
#                 [42.34285014, -71.06516235],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_a745c4edb83dd30ceaff8b92253d6e7f = L.marker(
#                 [42.3174536, -71.07327858],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_1b91eae7f9385ad9bf1897e4fb7f60ea = L.marker(
#                 [42.36489527, -71.06050249],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_d5f143d600f0c6dbe1f86ce737503b58 = L.marker(
#                 [42.28587471, -71.04247805],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_e0f666d40c861221e77291dd717d02a8 = L.marker(
#                 [42.33397571, -71.05463126],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_9329ef65267f156ca1ced8e67d8bd1c6 = L.marker(
#                 [42.28187061, -71.08751152],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_de6ca5de84e538d0d50eb70be30d557c = L.marker(
#                 [42.3169665, -71.08254058],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_05772c398175fd527d5b01f9aa909b6f = L.marker(
#                 [42.29851793, -71.07499608],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_8ef44bfa412c87bdb019df67d6ca5758 = L.marker(
#                 [42.37945053, -71.02770085],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_f9c91556fc85abec53165b95123f3e16 = L.marker(
#                 [42.38133666, -71.03026947],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_9f353187d8b10fc581303cdb1dd03c14 = L.marker(
#                 [42.36116347, -71.06391344],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_c299747bc2cfa225f831c8a3dfd2e30e = L.marker(
#                 [42.35174282, -71.0627594],
#                 {}
#             ).addTo(marker_cluster_494ff070f6e83e1c6fc8644e07edc448);
#
#
#             var marker_e40fd906cd49f59c7f77107b05f25ce9 = L.marker(
#                 [42.35913227, -71.07074326],
#                 {}

# %% [markdown]
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; background-color: #ffffff; color: navy;">Map3: Heatmap with folium.plugins.HeatMap()  &nbsp;&nbsp;&nbsp;&nbsp;</h1>
#
#  This shows the density of crime in different areas of the city, where yellow areas have relatively more criminal incidents.

# %%
# Create a base map
map3_boston = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositron', zoom_start=12)

# Add a heatmap to the base map
HeatMap(data=daytime_robberies[['Lat', 'Long']], radius=10).add_to(map3_boston)

# Display the map
map3_boston
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aef2690431d374debeaefffb68246a37 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aef2690431d374debeaefffb68246a37&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aef2690431d374debeaefffb68246a37 = L.map(
#                 &quot;map_aef2690431d374debeaefffb68246a37&quot;,
#                 {
#                     center: [42.32, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11cee9ecabfb63c4a4b2fe74946ddf53 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aef2690431d374debeaefffb68246a37);
#
#
#             var heat_map_15b9fa6eafcd29be7318fae089c3e4ee = L.heatLayer(
#                 [[42.28863337, -71.08990388], [42.30078455, -71.06000691], [42.3219697, -71.07242529], [42.34285014, -71.06516235], [42.3174536, -71.07327858], [42.36489527, -71.06050249], [42.28587471, -71.04247805], [42.33397571, -71.05463126], [42.28187061, -71.08751152], [42.3169665, -71.08254058], [42.29851793, -71.07499608], [42.37945053, -71.02770085], [42.38133666, -71.03026947], [42.36116347, -71.06391344], [42.35174282, -71.0627594], [42.35913227, -71.07074326], [42.35235362, -71.05815283], [42.29212974, -71.07175746], [42.33093363, -71.10956443], [42.28631799, -71.13407707], [42.28277895, -71.07135525], [42.37620267, -71.03979926], [42.34999733, -71.0810344], [42.28534033, -71.07118543], [42.37950444, -71.02857705], [42.30396336, -71.05924636], [42.32029322, -71.05676992], [42.32525618, -71.07922845], [42.35156343, -71.05701389], [42.34175462, -71.0685477], [42.28792347, -71.08815774], [42.34693807, -71.09266111], [42.32667817, -71.0714811], [42.28935481, -71.06767297], [42.37167264, -71.06326413], [42.27645319, -71.11297971], [42.36219081, -71.06223802], [42.33153805, -71.08015661], [42.30492239, -71.10298073], [42.3649755, -71.062044
# %% [markdown]
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; background-color: #ffffff; color: navy;">Display San Francisco Map with folium.Map() &nbsp;&nbsp;&nbsp;&nbsp;</h1>

# %%
# Create a map
sf_map = folium.Map(location=[37.78363773158004, -122.40941186660926], tiles='openstreetmap', zoom_start=10)

# Display the map
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a054b0e8b82426b68c3f91edd8b4000a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a054b0e8b82426b68c3f91edd8b4000a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a054b0e8b82426b68c3f91edd8b4000a = L.map(
#                 &quot;map_a054b0e8b82426b68c3f91edd8b4000a&quot;,
#                 {
#                     center: [37.78363773158004, -122.40941186660926],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_320e56e7f7f86d830aa419dc8a21dc5e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a054b0e8b82426b68c3f91edd8b4000a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Several arguments customize the appearance of the map:
# - `location` sets the initial center of the map. We use the latitude (42.32&deg; N) and longitude (-71.0589&deg; E) of the city of Boston.
# - `tiles` changes the styling of the map; in this case, we choose the [OpenStreetMap](https://www.openstreetmap.org/#map=10/42.32/-71.0589) style.  If you're curious, you can find the other options listed [here](https://github.com/python-visualization/folium/tree/master/folium/templates/tiles).
# - `zoom_start` sets the initial level of zoom of the map, where higher values zoom in closer to the map.

# %% [markdown]
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; background-color: #ffffff; color: navy;">Import Data &nbsp;&nbsp;&nbsp;&nbsp;</h1>

# %% [markdown]
# For the sake of data size, **df_sf_robbery.csv** only contains the crime information under **"Robbery"** category that happend during **weekdays**

# %%
df_sf = pd.read_csv("https://raw.githubusercontent.com/NorikaNarimatsu/DS4SG_Advanced_Dataviz/main/PCW/df_sf_robbery.csv")
df_sf.head()
# Out:
#    IncidntNum Category                                    Descript  DayOfWeek  \
# 0   160009956  ROBBERY  ROBBERY OF A CHAIN STORE WITH BODILY FORCE     Monday
# 1   160014836  ROBBERY       ROBBERY OF A CHAIN STORE WITH A KNIFE  Wednesday
# 2   160015486  ROBBERY                       ROBBERY, BODILY FORCE  Wednesday
# 3   160016951  ROBBERY            ROBBERY ON THE STREET, STRONGARM   Thursday
# 4   160016989  ROBBERY         ATTEMPTED ROBBERY WITH BODILY FORCE   Thursday
#
#                      Date   Time PdDistrict       Resolution  \
# 0  01/04/2016 12:00:00 AM  17:50    TARAVAL   ARREST, BOOKED
# 1  01/06/2016 12:00:00 AM  14:23   RICHMOND             NONE
# 2  01/06/2016 12:00:00 AM  17:20    MISSION  JUVENILE BOOKED
# 3  01/07/2016 12:00:00 AM  02:00    MISSION             NONE
# 4  01/07/2016 12:00:00 AM  10:55   SOUTHERN   ARREST, BOOKED
#
#                     Address           X          Y  \
# 0     3200 Block of 20TH AV -122.475647  37.728528
# 1  700 Block of CABRILLO ST -122.466559  37.775192
# 2         CAPP ST / 22ND ST -122.417661  37.755504
# 3       CASTRO ST / 17TH ST -122.435188  37.762670
# 4        5TH ST / TEHAMA ST -122.404408  37.781076
#
#                                 Location            PdId
# 0  (37.7285280627465, -122.475647460786)  16000995603044
# 1  (37.7751918267217, -122.466558780683)  16001483603042
# 2  (37.7555043420028, -122.417660640341)  16001548603074
# 3  (37.7626702770872, -122.435187699349)  16001695103014
# 4  (37.7810759636856, -122.404407887961)  16001698903474

# %% [markdown]
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; background-color: #ffffff; color: navy;">Map1: folium.Marker()  &nbsp;&nbsp;&nbsp;&nbsp;</h1>
#
# We add markers to the map with folium.Marker(). Each marker below corresponds to a different robbery.

# %%
# Create a map
map1_sf = folium.Map(location=[37.78363773158004, -122.40941186660926], tiles='cartodbpositron', zoom_start=13)

# Add points to the map
for idx, row in df_sf.iterrows():
    Marker([row['Y'], row['X']]).add_to(map1_sf)

# Display the map
map1_sf
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51a3de8c5332f7ea7d00c7458289b989 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51a3de8c5332f7ea7d00c7458289b989&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51a3de8c5332f7ea7d00c7458289b989 = L.map(
#                 &quot;map_51a3de8c5332f7ea7d00c7458289b989&quot;,
#                 {
#                     center: [37.78363773158004, -122.40941186660926],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ccc232fb5999fb62b0638e7c5311480e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_af001263d86e1464758bca7776c4859d = L.marker(
#                 [37.7285280627465, -122.475647460786],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_6098ce08b161782ce1bd441e6d9da8f2 = L.marker(
#                 [37.7751918267217, -122.466558780683],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_2d997ce642e638893e8a3ba212c3d766 = L.marker(
#                 [37.7555043420028, -122.417660640341],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_7bf10317778914771a7134e09feb14e9 = L.marker(
#                 [37.7626702770872, -122.435187699349],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_7eb1024c6bf1cd499b77d5dbdacd7300 = L.marker(
#                 [37.7810759636856, -122.404407887961],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_b8d1590e6467969859d937dcc0b61875 = L.marker(
#                 [37.7522391652625, -122.418448186101],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_f94ac69ca1871d3a32481b7c61d7d627 = L.marker(
#                 [37.7594884557036, -122.417970955091],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_3e232b604b668ab49c797243ab9641de = L.marker(
#                 [37.748520075538, -122.420247296449],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_e3803e8e593a44835386f3f6bffe802b = L.marker(
#                 [37.8076403511907, -122.419919493342],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_c4fa10c4e912a0b1438fce35b80171d5 = L.marker(
#                 [37.7905094151595, -122.417368206741],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_4130d761cf24c16e9b8ac082874983a0 = L.marker(
#                 [37.7623151800313, -122.462973519258],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_44fc50f82718fce1443bf9f1bca190a7 = L.marker(
#                 [37.769411384942, -122.410932750782],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_c84e5cf7e3276c7522c3dbb230df0553 = L.marker(
#                 [37.7505727393139, -122.41940150486],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_85f8d775eeac7ab120e129a109bf4aed = L.marker(
#                 [37.7610244167023, -122.419212198636],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_2915aa11b0d272183535db36882edb15 = L.marker(
#                 [37.743584765874, -122.421264331104],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_606d6e7c85b430b3beb2daa0792af80f = L.marker(
#                 [37.7905094151595, -122.417368206741],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_a663ca3046a738cf49ee4aecf8aea069 = L.marker(
#                 [37.7959699858361, -122.413826855695],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_294d826bd8e068e0531c01b5e4957ae6 = L.marker(
#                 [37.7837899781799, -122.419387180576],
#                 {}
#             ).addTo(map_51a3de8c5332f7ea7d00c7458289b989);
#
#
#             var marker_bda7d8dfb44a757ebdf7a9c8bc411910 = L.marker(
#                 [37.7303066365695, -122.47011059238],
#                 {}
#             ).addTo(map_51a3de8c533

# %% [markdown]
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; background-color: #ffffff; color: navy;">Map2: folium.plugins.MarkerCluster()  &nbsp;&nbsp;&nbsp;&nbsp;</h1>

# %% [markdown]
# If we have a lot of markers to add, `folium.plugins.MarkerCluster()` can help to declutter the map.  Each marker is added to a `MarkerCluster` object.

# %%
# Create the map
map2_sf = folium.Map(location=[37.78363773158004, -122.40941186660926], tiles='cartodbpositron', zoom_start=13)

# Add points to the map
mc = MarkerCluster()
for idx, row in df_sf.iterrows():
    if not math.isnan(row['X']) and not math.isnan(row['Y']):
        mc.add_child(Marker([row['Y'], row['X']]))
map2_sf.add_child(mc)

# Display the map
map2_sf
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4133185953d65108d61184aa0b7c10f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4133185953d65108d61184aa0b7c10f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4133185953d65108d61184aa0b7c10f = L.map(
#                 &quot;map_f4133185953d65108d61184aa0b7c10f&quot;,
#                 {
#                     center: [37.78363773158004, -122.40941186660926],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e11e00a70b4309fcd5a2066abb71afdc = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f4133185953d65108d61184aa0b7c10f);
#
#
#             var marker_cluster_a3af1dd3973645cf4adec6ad419cc794 = L.markerClusterGroup(
#                 {}
#             );
#             map_f4133185953d65108d61184aa0b7c10f.addLayer(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_dc74ebe4f3f349ed895f4a4eeeddb400 = L.marker(
#                 [37.7285280627465, -122.475647460786],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_3e7666a26b8d1a83ad2d2c478fb9ec46 = L.marker(
#                 [37.7751918267217, -122.466558780683],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_4e4e3acf41ff407308f833914531b685 = L.marker(
#                 [37.7555043420028, -122.417660640341],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_07c462f91f1e785930374a470c0bd2b8 = L.marker(
#                 [37.7626702770872, -122.435187699349],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_f1abcf7f457dc7139150a523d5578e6f = L.marker(
#                 [37.7810759636856, -122.404407887961],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_055e3f89591b8e892e8356197f494abf = L.marker(
#                 [37.7522391652625, -122.418448186101],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_ea5e85f944074caaf6b42fa62ff015b4 = L.marker(
#                 [37.7594884557036, -122.417970955091],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_f436c80ea473e27be8a98e8249d3218f = L.marker(
#                 [37.748520075538, -122.420247296449],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_2cb15a69769d4debe4de52b1d44996ef = L.marker(
#                 [37.8076403511907, -122.419919493342],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_f9fd9a45d2f422d25089e4390e5a3a90 = L.marker(
#                 [37.7905094151595, -122.417368206741],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_f819612f67ea1ae978ccc33dcaf671b6 = L.marker(
#                 [37.7623151800313, -122.462973519258],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_1a30662cd2f5e6b1f4b91ea7349fca01 = L.marker(
#                 [37.769411384942, -122.410932750782],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_b778b0cda56bd921c00fcaf6076430f4 = L.marker(
#                 [37.7505727393139, -122.41940150486],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_0193f4ca9e06c2a26d9f2d515dc549cb = L.marker(
#                 [37.7610244167023, -122.419212198636],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4adec6ad419cc794);
#
#
#             var marker_048de119c0ec4f32f0bf0f13be06a5e8 = L.marker(
#                 [37.743584765874, -122.421264331104],
#                 {}
#             ).addTo(marker_cluster_a3af1dd3973645cf4

# %% [markdown]
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; background-color: #ffffff; color: navy;">Map3: Heatmap with folium.plugins.HeatMap()  &nbsp;&nbsp;&nbsp;&nbsp;</h1>
#
#  This shows the density of crime in different areas of the city, where yellow areas have relatively more criminal incidents.

# %%
# Create a base map
map3_sf = folium.Map(location=[37.78363773158004, -122.40941186660926], tiles='cartodbpositron', zoom_start=12)

# Add a heatmap to the base map
HeatMap(data=df_sf[['Y', 'X']], radius=10).add_to(map3_sf)

# Display the map
map3_sf
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da6ea1c1e17fde3a984566b0498feba8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da6ea1c1e17fde3a984566b0498feba8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da6ea1c1e17fde3a984566b0498feba8 = L.map(
#                 &quot;map_da6ea1c1e17fde3a984566b0498feba8&quot;,
#                 {
#                     center: [37.78363773158004, -122.40941186660926],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_404eb8d4fba7c68fb01312b2aa5df0a0 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map